# %%
from datasets import load_dataset

# This will download to the Hugging Face cache on that machine
ds = load_dataset("openslr/librispeech_asr", "clean")  
# or with split
ds_test = load_dataset("openslr/librispeech_asr", "clean", split="test")
ds_train = load_dataset("openslr/librispeech_asr", "clean", split="train.100")
ds_dev   = load_dataset("openslr/librispeech_asr", "clean", split="validation")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# ...
# Resolving data files:   0%|          | 0/48 [00:00<?, ?it/s]
# clean/test/0000.parquet:   0%|          | 0.00/350M [00:00<?, ?B/s]
# clean/train.100/0000.parquet:   0%|          | 0.00/470M [00:00<?, ?B/s]
# clean/train.100/0001.parquet:   0%|          | 0.00/481M [00:00<?, ?B/s]
# clean/train.100/0002.parquet:   0%|          | 0.00/463M [00:00<?, ?B/s]
# clean/train.100/0003.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# clean/train.100/0004.parquet:   0%|          | 0.00/487M [00:00<?, ?B/s]
# clean/train.100/0005.parquet:   0%|          | 0.00/453M [00:00<?, ?B/s]
# clean/train.100/0006.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# clean/train.100/0007.parquet:   0%|          | 0.00/452M [00:00<?, ?B/s]
# clean/train.100/0008.parquet:   0%|          | 0.00/465M [00:00<?, ?B/s]
# clean/train.100/0009.parquet:   0%|          | 0.00/445M [00:00<?, ?B/s]
# clean/train.100/0010.parquet:   0%|          | 0.00/454M [00:00<?, ?B/s]
# ...

# %%
# Save to disk in a folder “/home/youruser/hub_data/librispeech”
save_path = "./hub_data/librispeech"
ds = load_dataset("openslr/librispeech_asr", "clean")
ds.save_to_disk(save_path)
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/2703 [00:00<?, ? examples/s]

# %%
from datasets import load_from_disk
ds = load_from_disk(save_path)
# Out:
# Loading dataset from disk:   0%|          | 0/48 [00:00<?, ?it/s]

# %%
import os

def print_tree(root, prefix=""):
    # Get entries sorted so it's reproducible
    entries = sorted(os.listdir(root))
    for i, name in enumerate(entries):
        path = os.path.join(root, name)
        is_last = (i == len(entries) - 1)
        # Choose branch characters
        branch = "└── " if is_last else "├── "
        print(prefix + branch + name)
        if os.path.isdir(path):
            extension = "    " if is_last else "│   "
            print_tree(path, prefix + extension)

# Example usage:
root_path = "./hub_data"   # adjust to your root folder
print(root_path)
print_tree(root_path)
# Out:
# ./hub_data
# └── librispeech
#     ├── dataset_dict.json
#     ├── test
#     │   ├── data-00000-of-00001.arrow
#     │   ├── dataset_info.json
#     │   └── state.json
#     ├── train.100
#     │   ├── data-00000-of-00014.arrow
#     │   ├── data-00001-of-00014.arrow
#     │   ├── data-00002-of-00014.arrow
#     │   ├── data-00003-of-00014.arrow
#     │   ├── data-00004-of-00014.arrow
#     │   ├── data-00005-of-00014.arrow
#     │   ├── data-00006-of-00014.arrow
#     │   ├── data-00007-of-00014.arrow
#     │   ├── data-00008-of-00014.arrow
#     │   ├── data-00009-of-00014.arrow
#     │   ├── data-00010-of-00014.arrow
#     │   ├── data-00011-of-00014.arrow
#     │   ├── data-00012-of-00014.arrow
#     │   ├── data-00013-of-00014.arrow
#     │   ├── dataset_info.json
#     │   └── state.json
#     ├── train.360
#     │   ├── data-00000-of-00048.arrow
#     │   ├── data-00001-of-00048.arrow
#     │   ├── data-00002-of-00048.arrow
#     │   ├── data-00003-of-00048.arrow
# ...

# %%
from datasets import load_dataset

# 1. Download the "other" configuration
# This contains: train.500, validation (other), test (other)
print("Downloading Librispeech 'other' configuration...")
ds_other = load_dataset("openslr/librispeech_asr", "other")

# 2. Save to disk (keep it separate from your 'clean' folder)
save_path_other = "../hub_data/librispeech_other"
ds_other.save_to_disk(save_path_other)
print(f"Saved 'other' dataset to {save_path_other}")
# Out:
# ...
# Saving the dataset (1/1 shards): 100%|██████████| 2864/2864 [00:00<00:00, 4603.82 examples/s]
# Saved 'other' dataset to ../hub_data/librispeech_other
